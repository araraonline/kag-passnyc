# %% [markdown]
# # Measuring the applicants gap - Cross Validation
#
# Each school has a determined set of characteristics. Based on these characteristics, we can estimate how many students from each school will sit for SHSAT. Based on this estimation, we come up with a gap, that is the difference between the expected amount of SHSAT takers and the actual amount. PASSNYC actions should be made upon this gap, and its effect can be estimated based upon the size of this gap. So, in this kernel here, I will estimate the applicants gap for each school, providing a good parameter for PASSNYC when it is going to choose new schools. How far from schools with the same characteristics this school is...
#
# **Assumptions**:
#
# - The number of SHSAT applicants for each school keeps somewhat constant

# %% [markdown]
# # Data
#
# To create this model, I will joined dataset from a variety of sources. The main objective was to gather information from the schools and students that had the opportunity to take the SHSAT in the end of 2017.
#
# ![data timeline](../data/keep/timeline.png)
#
# ## School Locations
#
# Latitude and longitude for each school. From these, I could also extract the borough each school is located at.
#
# ## Test results
#
# NYS Tests Results for ELA (English Language Arts) and Math. Our focus group took them on the 7th grade in 2017.
#
# ## SHSAT Testers and Offers
#
# Contains the amount of SHSAT Testers and offers for each school in 2017
#
# ## Quality Report
#
# We used it to extract demographics information for each school for the 2016-17 school year.
#
# *Wouldn't it be better to use the 2017-18 demographics?*
#
# -- compare with direct demographics --
#
# Overall, it may be the right choice, as the quality reports *seems* to use data from the end of the year for their demographics assessments.

# %% [markdown]
# # Prepare the data

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
from scipy.special import logit, expit
from sklearn.metrics import median_absolute_error, r2_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import scale

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', None)

# %%
def psize(df):
    print("rows = {}".format(df.shape[0]))

# %%
df = pd.read_pickle('../data/process/schools2017.pkl')
psize(df)
df.head(2)
# Out:
# rows = 594
#                            School Name  Charter School?    Borough   Latitude  \
# DBN
# 01M034  P.S. 034 Franklin D. Roosevelt              0.0  manhattan  40.726008
# 01M140          P.S. 140 Nathan Straus              0.0  manhattan  40.719148
#
#         Longitude  Percent Asian  Percent Black  Percent Hispanic  \
# DBN
# 01M034 -73.975058          0.053          0.297             0.614
# 01M140 -73.983769          0.044          0.121             0.794
#
#         Percent White  Percent Other  Percent English Language Learners  \
# DBN
# 01M034           0.03          0.006                              0.080
# 01M140           0.03          0.011                              0.124
#
#         Percent Students with Disabilities  \
# DBN
# 01M034                               0.380
# 01M140                               0.338
#
#         Percent of Students Chronically Absent  Economic Need Index  \
# DBN
# 01M034                                   0.305                0.872
# 01M140                                   0.395                0.853
#
#         Mean Scale Score - ELA  % Level 2 - ELA  % Level 3 - ELA  \
# DBN
# 01M034                298.2778         59.25926         22.22222
# 01M140                297.4545         60.00000         21.81818
#
#         % Level 4 - ELA  Mean Scale Score - Math  % Level 2 - Math  \
# DBN
# 01M034         1.851852                 285.9423          34.61538
# 01M140         1.818182                 291.2456          38.59649
#
#         % Level 3 - Math  % Level 4 - Math  # Students in HS Admissions  \
# DBN
# 01M034          13.46154               0.0                         58.0
# 01M140          14.03509               0.0                         67.0
#
#         # SHSAT Testers  # SHSAT Offers  % SHSAT Testers  % SHSAT Offers
# DBN
# 01M034              6.0             NaN         0.103448             NaN
# 01M140              6.0             NaN         0.089552             NaN

# %% [markdown]
# Drop rows with unkown values

# %%
df = df[df.loc[:, :'# Students in HS Admissions'].notnull().all(axis=1)]
psize(df)
# Out:
# rows = 578

# %% [markdown]
# # Create a model

# %%
inputs = df[[
    'Mean Scale Score - ELA',
    '% Level 2 - ELA',
    '% Level 3 - ELA',
    '% Level 4 - ELA',
    'Mean Scale Score - Math',
    '% Level 2 - Math',
    '% Level 3 - Math',
    '% Level 4 - Math',
    'Percent of Students Chronically Absent',
]].copy()
outputs = logit(df['% SHSAT Testers'])

# %%
inputs = inputs.apply(scale, axis=0)  # standardize columns to avoid numerical instability
inputs['Constant'] = 1.0

# %%
model = sm.RLM(outputs, inputs, M=sm.robust.norms.HuberT(), missing='drop')  # drop observations when fitting the model
results = model.fit()
predictions = model.predict(results.params, exog=inputs)

# %% [markdown]
# ---

# %% [markdown]
# ### Cross-validation

# %%
# inputs we will cross validate

def means(df):
    return df[['Constant', 'Percent of Students Chronically Absent',
               'Mean Scale Score - ELA',
               'Mean Scale Score - Math']]

def means4(df):
    return df[['Constant', 'Percent of Students Chronically Absent',
               'Mean Scale Score - ELA', '% Level 4 - ELA',
               'Mean Scale Score - Math', '% Level 4 - Math']]

def means34(df):
    return df[['Constant', 'Percent of Students Chronically Absent',
               'Mean Scale Score - ELA', '% Level 3 - ELA', '% Level 4 - ELA',
               'Mean Scale Score - Math', '% Level 3 - Math', '% Level 4 - Math']]

def means234(df):
    return df[['Constant', 'Percent of Students Chronically Absent',
               'Mean Scale Score - ELA', '% Level 2 - ELA', '% Level 3 - ELA', '% Level 4 - ELA',
               'Mean Scale Score - Math', '% Level 2 - Math', '% Level 3 - Math', '% Level 4 - Math']]

def pca(df, n_components):
    out = df[['Constant', 'Percent of Students Chronically Absent']]
    inside = df.loc[:, 'Mean Scale Score - ELA':'% Level 4 - Math']
    
    arr = PCA(n_components, random_state=1).fit_transform(df)    
    arr_df = pd.DataFrame(arr, index=df.index, columns=['PC{}'.format(i) for i in range(1, n_components + 1)])
    
    return pd.concat([out, arr_df], axis=1)

# %%
functions = [
    means,
    means4,
    means34,
    means234,  # basecase
    lambda x: pca(x, 1),
    lambda x: pca(x, 2),
    lambda x: pca(x, 3),
    lambda x: pca(x, 4),
    lambda x: pca(x, 5),
    lambda x: pca(x, 6),
    lambda x: pca(x, 7),
    lambda x: pca(x, 8),  # basecase
]

function_names = [
    'means',
    'means4',
    'means34',
    'means234',
    'pca1',
    'pca2',
    'pca3',
    'pca4',
    'pca5',
    'pca6',
    'pca7',
    'pca8',    
]

# only use non-null entries
exog = inputs[outputs.notnull()]
endog = outputs[outputs.notnull()]

# cross-validation
cv_results = []
for fn, fn_name in zip(functions, function_names):
    scores = []
    
    x = fn(exog)
    y = endog.copy()
    
    cv = KFold(n_splits=10, shuffle=True, random_state=1)
    
    from sklearn.model_selection import RepeatedKFold
    cv = RepeatedKFold(n_splits=5, n_repeats=10, random_state=1)
    
    for train, test in cv.split(x):
        x_train = x.iloc[train]
        x_test = x.iloc[test]
        y_train = y.iloc[train]
        y_test = y.iloc[test]
        
        model = sm.RLM(y_train, x_train, M=sm.robust.norms.HuberT())
        results = model.fit()
        predictions = model.predict(results.params, exog=x_test)
        scores.append(median_absolute_error(y_test, predictions))
        
    scores_mean = np.mean(scores)
    scores_std = np.std(scores)
    cv_result = (fn_name, scores_mean, scores_std)
    cv_results.append(cv_result)
    
cv_results_df = pd.DataFrame(cv_results, columns=['fn_name', 'mad__mean', 'mad__std'])

# %%
cv_results_df
# Out:
#      fn_name  mad__mean  mad__std
# 0      means   0.416599  0.029709
# 1     means4   0.422657  0.027355
# 2    means34   0.408403  0.029384
# 3   means234   0.410716  0.029747
# 4       pca1   0.375644  0.033241
# 5       pca2   0.384402  0.031545
# 6       pca3   0.385611  0.030110
# 7       pca4   0.396735  0.026656
# 8       pca5   0.408325  0.026341
# 9       pca6   0.407536  0.029182
# 10      pca7   0.407751  0.029150
# 11      pca8   0.410716  0.029747

# %%
# pca1 produces the inputs that best fit the middle range
# not fitting too much on the outliers, this is what we want!

x = pca(inputs, 1)

model = sm.RLM(outputs, x, M=sm.robust.norms.HuberT(), missing='drop')  # drop observations when fitting the model
results = model.fit()
predictions = model.predict(results.params, exog=x)

# %% [markdown]
# Note: By using PCA and dropping PC's, we are avoiding some kind of information from the inputs. While this produces a tighter correspondence in the middle values, it may create some outliers that are not actually outliers, outliers that would be guessed by the inputs we have, it's jsut that we cleaned information from the input.
#
# This need to be thought out thoroughly.
#
# If we use R2 score instead, we may see if we are overfitting.

# %%
functions = [
    means,
    means4,
    means34,
    means234,  # basecase
    lambda x: pca(x, 1),
    lambda x: pca(x, 2),
    lambda x: pca(x, 3),
    lambda x: pca(x, 4),
    lambda x: pca(x, 5),
    lambda x: pca(x, 6),
    lambda x: pca(x, 7),
    lambda x: pca(x, 8),  # basecase
]

function_names = [
    'means',
    'means4',
    'means34',
    'means234',
    'pca1',
    'pca2',
    'pca3',
    'pca4',
    'pca5',
    'pca6',
    'pca7',
    'pca8',    
]

# only use non-null entries
exog = inputs[outputs.notnull()]
endog = outputs[outputs.notnull()]

# cross-validation
cv_results = []
for fn, fn_name in zip(functions, function_names):
    scores = []
    
    x = fn(exog)
    y = endog.copy()
    
    cv = KFold(n_splits=10, shuffle=True, random_state=1)
    
    from sklearn.model_selection import RepeatedKFold
    cv = RepeatedKFold(n_splits=5, n_repeats=10, random_state=1)
    
    for train, test in cv.split(x):
        x_train = x.iloc[train]
        x_test = x.iloc[test]
        y_train = y.iloc[train]
        y_test = y.iloc[test]
        
        model = sm.RLM(y_train, x_train, M=sm.robust.norms.HuberT())
        results = model.fit()
        predictions = model.predict(results.params, exog=x_test)
        scores.append(r2_score(y_test, predictions))
        
    scores_mean = np.mean(scores)
    scores_std = np.std(scores)
    cv_result = (fn_name, scores_mean, scores_std)
    cv_results.append(cv_result)
    
cv_results_df = pd.DataFrame(cv_results, columns=['fn_name', 'r2__mean', 'r2__std'])
cv_results_df
# Out:
#      fn_name  r2__mean   r2__std
# 0      means  0.547032  0.064348
# 1     means4  0.573219  0.068138
# 2    means34  0.574243  0.068827
# 3   means234  0.570490  0.070613
# 4       pca1  0.570516  0.069935
# 5       pca2  0.569698  0.072495
# 6       pca3  0.572205  0.073242
# 7       pca4  0.571729  0.074141
# 8       pca5  0.573211  0.069698
# 9       pca6  0.573768  0.069034
# 10      pca7  0.572269  0.069956
# 11      pca8  0.570490  0.070613

# %% [markdown]
# Dropping the Number of 2s may be wise.

# %%
present = outputs.notnull()  # boolean mask
outputs_p = outputs[present]
predictions_p = predictions[present]
residuals = outputs_p - predictions_p

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                     Robust linear Model Regression Results
# ==============================================================================
# Dep. Variable:        % SHSAT Testers   No. Observations:                  523
# Model:                            RLM   Df Residuals:                      520
# Method:                          IRLS   Df Model:                            2
# Norm:                          HuberT
# Scale Est.:                       mad
# Cov Type:                          H1
# Date:                Thu, 02 Aug 2018
# Time:                        15:49:15
# No. Iterations:                    20
# ==========================================================================================================
#                                              coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# Constant                                  -0.9212      0.026    -34.983      0.000      -0.973      -0.870
# Percent of Students Chronically Absent     0.0467      0.043      1.092      0.275      -0.037       0.130
# PC1                                        0.3387      0.017     20.444      0.000       0.306       0.371
# ==========================================================================================================
#
# If the model instance has been used for another fit with different fit
# parameters, then the fit options might not be the correct ones anymore .
# """

# %%
print("R2 Score: {}".format(r2_score(outputs_p, predictions_p)))
print("MAD: {}".format(median_absolute_error(outputs_p, predictions_p)))
# Out:
# R2 Score: 0.5819392537012622
# MAD: 0.3634204137736727

# %%
plt.figure(figsize=(16,10))
plt.plot(expit(predictions_p), expit(outputs_p), '.')
plt.plot([0, 1], [0, 1], '--')
plt.xlim(0, 1)
plt.ylim(0, 1)
plt.xlabel("Predicted percentage of students taking SHSAT")  # compare with HS Admission Process applicants
plt.ylabel("Actual percentage of students taking SHSAT");

# %%
plt.figure(figsize=(16,10))
plt.plot(predictions_p, residuals, '.')
plt.axhline(0, linestyle='--', color='k')
plt.xlabel("Predicted logit")
plt.ylabel("Residual logit")
# Out:
# Text(0,0.5,'Residual logit')

# %% [markdown]
# ## Estimate the gap in various units

# %% [markdown]
# ### Actual Values

# %%
# min and max for schools with 0->5 SHSAT applicants

present = outputs.notnull()
hs_counts = df['# Students in HS Admissions'][~present]

# min values
min_table = pd.DataFrame({
    'logit': -np.inf,
    'pct': 0,
    'cnt': 0,
}, index=hs_counts.index)

# max values
cnt = 5
pct = 5 / hs_counts
odds = pct / (1 - pct)
logit_ = np.log(odds)
max_table = pd.DataFrame({
    'logit': logit_,
    'pct': pct,
    'cnt': cnt,
}, index=hs_counts.index)

# visualize
min_table.join(max_table, lsuffix='min', rsuffix='max').head()
# Out:
#         logitmin  pctmin  cntmin  logitmax    pctmax  cntmax
# DBN
# 01M188      -inf       0       0 -2.379546  0.084746       5
# 02M225      -inf       0       0 -1.163151  0.238095       5
# 02M655      -inf       0       0 -1.223775  0.227273       5
# 03M076      -inf       0       0 -2.379546  0.084746       5
# 03M149      -inf       0       0 -1.481605  0.185185       5

# %%
# values for schools with 6+ SHSAT applicants

present = outputs.notnull()
hs_counts = df['# Students in HS Admissions'][present]

cnt = df['# SHSAT Testers'][present]
pct = cnt / hs_counts
odds = pct / (1 - pct)
logit_ = np.log(odds)

table = pd.DataFrame({
    'logit': logit_,
    'pct': pct,
    'cnt': cnt,
}, index=hs_counts.index)
table.cnt

table.head()
# Out:
#            logit       pct   cnt
# DBN
# 01M034 -2.159484  0.103448   6.0
# 01M140 -2.319114  0.089552   6.0
# 01M184  1.160170  0.761364  67.0
# 01M301 -1.290984  0.215686  11.0
# 01M332 -1.442384  0.191176  13.0

# %% [markdown]
# ### Estimated values

# %%
hs_counts = df['# Students in HS Admissions']

logit_ = predictions
odds = np.exp(logit_)
pct = odds / (1 + odds)
cnt = pct * hs_counts

exp_table = pd.DataFrame({
    'logit': logit_,
    'pct': pct,
    'cnt': cnt,
}, index=hs_counts.index)
exp_table.head()
# Out:
#            logit       pct        cnt
# DBN
# 01M034 -1.572512  0.171859   9.967794
# 01M140 -1.631225  0.163663  10.965396
# 01M184  0.532934  0.630167  55.454716
# 01M188 -1.624926  0.164527   9.707071
# 01M301 -1.405411  0.196959  10.044904

# %% [markdown]
# ### Differences

# %%
min_diffs = (min_table - exp_table).dropna()
max_diffs = (max_table - exp_table).dropna()
diffs = (table - exp_table).dropna()

min_diffs.join(max_diffs, lsuffix='min', rsuffix='max').head()
# Out:
#         logitmin    pctmin    cntmin  logitmax    pctmax    cntmax
# DBN
# 01M188      -inf -0.164527 -9.707071 -0.754620 -0.079781 -4.707071
# 02M225      -inf -0.412193 -8.656048 -0.808243 -0.174098 -3.656048
# 02M655      -inf -0.160177 -3.523898  0.433135  0.067096  1.476102
# 03M076      -inf -0.160402 -9.463690 -0.724303 -0.075656 -4.463690
# 03M149      -inf -0.159472 -4.305738  0.180559  0.025713  0.694262

# %% [markdown]
# ### Join

# %%
# students num
hs_counts = df['# Students in HS Admissions'].to_frame()

# actual
actual = pd.DataFrame({
    'Actual Cnt (min)': pd.concat([min_table, table])['cnt'],
    'Actual Cnt (max)': pd.concat([max_table, table])['cnt'],
    'Actual Pct (min)': pd.concat([min_table, table])['pct'],
    'Actual Pct (max)': pd.concat([max_table, table])['pct'],
})

# expected
expected = pd.DataFrame({
    'Predicted Cnt': exp_table['cnt'],
    'Predicted Pct': exp_table['pct'],
})

# difference
difference = pd.DataFrame({
    'Diff Cnt (min)': pd.concat([min_diffs, diffs])['cnt'],
    'Diff Cnt (max)': pd.concat([max_diffs, diffs])['cnt'],
    'Diff Pct (min)': pd.concat([min_diffs, diffs])['pct'],
    'Diff Pct (max)': pd.concat([max_diffs, diffs])['pct'],
#     'Diff Logit (min)': pd.concat([min_diffs, diffs])['logit'],
    'Diff Logit': pd.concat([max_diffs, diffs])['logit'],
})

# join
everything = hs_counts.join(actual).join(expected).join(difference)
everything = everything.sort_values(['Diff Logit'])  # when entry is unkown, we assume 5 students
# logit needs explanation
everything.head()
# Out:
#         # Students in HS Admissions  Actual Cnt (min)  Actual Cnt (max)  \
# DBN
# 02M408                         33.0               9.0               9.0
# 84M336                         94.0              15.0              15.0
# 84M353                        101.0               0.0               5.0
# 09X117                        175.0               0.0               5.0
# 32K554                         59.0              22.0              22.0
#
#         Actual Pct (min)  Actual Pct (max)  Predicted Cnt  Predicted Pct  \
# DBN
# 02M408          0.272727          0.272727      24.202615       0.733413
# 84M336          0.159574          0.159574      52.589193       0.559460
# 84M353          0.000000          0.049505      25.383446       0.251321
# 09X117          0.000000          0.028571      24.184993       0.138200
# 32K554          0.372881          0.372881      42.120238       0.713902
#
#         Diff Cnt (min)  Diff Cnt (max)  Diff Pct (min)  Diff Pct (max)  \
# DBN
# 02M408      -15.202615      -15.202615       -0.460685       -0.460685
# 84M336      -37.589193      -37.589193       -0.399885       -0.399885
# 84M353      -25.383446      -20.383446       -0.251321       -0.201816
# 09X117      -24.184993      -19.184993       -0.138200       -0.109629
# 32K554      -20.120238      -20.120238       -0.341021       -0.341021
#
#         Diff Logit
# DBN
# 02M408   -1.992835
# 84M336   -1.900366
# 84M353   -1.863332
# 09X117   -1.696039
# 32K554   -1.434288

# %%
a = df.join(everything[['Diff Cnt (min)']]).reindex(everything.index)
a[(a['% SHSAT Testers'] < 0.2) &
  (a['Borough'] != 'manhattan') &
  (a['Percent Black'] + a['Percent Hispanic'] + a['Percent Other'] >= 0.8)]
# Out:
#                                               School Name  Charter School?  \
# DBN
# 32K162                          J.H.S. 162 The Willoughby              0.0
# 84X482  Dr. Richard Izquierdo Health and Science Chart...              1.0
# 29Q259  Pathways College Preparatory School: A College...              0.0
# 10X037           P.S. X037 - Multiple Intelligence School              0.0
# 09X004                    P.S./M.S. 004 Crotona Park West              0.0
# 07X221    South Bronx Preparatory: A College Board School              0.0
# 19K171                           I.S. 171 Abraham Lincoln              0.0
# 19K422                      Spring Creek Community School              0.0
# 09X219                        I.S. 219 New Venture School              0.0
# 19K404                          Academy for Young Writers              0.0
# 08X302                         M.S. 302 Luisa Dessus Cruz              0.0
# 12X211                                           P.S. 211              0.0
# 10X225             Theatre Arts Production Company School              0.0
# 15K448  Brooklyn Secondary School for Collaborative St...              0.0
# 32K291                            J.H.S. 291 Roland Hayes              0.0
# 29Q356                     Community Voices Middle School              0.0
# 32K349                     I.S. 349 Math, Science & Tech.              0.0
# 29Q147                        P.S./M.S. 147 Ronald McNair              0.0
# 10X391                     The Angelo Patri Middle School              0.0
# 14K050                           J.H.S. 050 John D. Wells              0.0
# 84R067         John W. Lavelle Preparatory Charter School              1.0
# 24Q311                     Corona Arts & Sciences Academy              0.0
# 19K760                     Highland Park Community School              0.0
# 24Q061                         I.S. 061 Leonardo Da Vinci              0.0
# 19K662                       Liberty Avenue Middle School              0.0
# 07X296              South Bronx Academy for Applied Media              0.0
# 29Q138                              P.S./M.S. 138 Sunrise              0.0
# 09X303           I.S. X303 Leadership & Community Service              0.0
# 13K266     M.S. K266 - Park Place Community Middle School              0.0
# 14K586                             Lyons Community School              0.0
# 09X505       Bronx School for Law, Government and Justice              0.0
# 12X217                          School of Performing Arts              0.0
# 16K057                           J.H.S. 057 Whitelaw Reid              0.0
# 27Q105                            P.S. 105 The Bay School              0.0
# 32K562      Evergreen Middle School for Urban Exploration              0.0
# 12X341                                     Accion Academy              0.0
# 07X223  M.S. 223 The Laboratory School of Finance and ...              0.0
# 15K136                          I.S. 136 Charles O. Dewey              0.0
# 07X298                        Academy of Public Relations              0.0
# 12X372    Urban Assembly School for Wildlife Conservation              0.0
# 10X254                                           I.S. 254              0.0
# 30Q127           P.S. 127 Aerospace Science Magnet School              0.0
# 23K644                     Eagle Academy for Young Men II              0.0
# 22K109                                           P.S. 109              0.0
# 09X313          I.S. 313 School of Leadership Development              0.0
# 09X327        Comprehensive Model School Project M.S. 327              0.0
# 84K730                      Summit Academy Charter School              1.0
# 19K409                       East New York Family Academy              0.0
# 84X492   South Bronx Early College Academy Charter School              1.0
# 84K757                          Unity Prep Charter School              1.0
# 09X339          9.090909          0.699301                        172.0
# 19K364          5.263158          1.052632                        110.0
# 12X384          3.076923          0.000000                         72.0
# 09X325          5.555556          1.111111                        115.0
# 17K722          8.196721          0.000000                         72.0
# 23K284          8.000000          2.000000                         50.0
# 19K654          7.777778          0.000000                         89.0
# 19K663          6.382979          0.000000                         63.0
# 09X323          5.343511          0.000000                        158.0
#
#         # SHSAT Testers  # SHSAT Offers  % SHSAT Testers  % SHSAT Offers  \
# DBN
# 32K162              8.0             NaN         0.049689             NaN
# 84X482              7.0             NaN         0.063636             NaN
# 29Q259              6.0             NaN         0.082192             NaN
# 10X037              6.0             NaN         0.085714             NaN
# 09X004              7.0             NaN         0.112903             NaN
# 07X221              8.0             NaN         0.082474             NaN
# 19K171             11.0             NaN         0.072848             NaN
# 19K422              6.0             NaN         0.086957             NaN
# 09X219              7.0             NaN         0.065421             NaN
# 19K404              7.0             NaN         0.097222             NaN
# 08X302             13.0             NaN         0.078313             NaN
# 12X211              7.0             NaN         0.082353             NaN
# 10X225              6.0             NaN         0.117647             NaN
# 15K448              6.0             NaN         0.067416             NaN
# 32K291              8.0             NaN         0.074766             NaN
# 29Q356              9.0             NaN         0.090000             NaN
# 32K349              7.0             NaN         0.085366             NaN
# 29Q147              9.0             NaN         0.113924             NaN
# 10X391             17.0             NaN         0.089474             NaN
# 14K050              7.0             NaN         0.087500             NaN
# 84R067             16.0             NaN         0.141593             NaN
# 24Q311             16.0             NaN         0.133333             NaN
# 19K760             10.0             NaN         0.104167             NaN
# 24Q061             93.0             NaN         0.129888             NaN
# 19K662             12.0             NaN         0.078947             NaN
# 07X296              6.0             NaN         0.070588             NaN
# 29Q138             10.0             NaN         0.098039             NaN
# 09X303             16.0             NaN         0.122137             NaN
# 13K266              8.0             NaN         0.119403             NaN
# 14K586              6.0             NaN         0.083333             NaN
# 09X505             13.0             NaN         0.146067             NaN
# 12X217              8.0             NaN         0.083333             NaN
# 16K057              9.0             NaN         0.111111             NaN
# 27Q105              7.0             NaN         0.085366             NaN
# 32K562             10.0             NaN         0.104167             NaN
# 12X341              7.0             NaN         0.127273             NaN
# 07X223             18.0             NaN         0.181818             NaN
# 15K136             18.0             NaN         0.106509             NaN
# 07X298              9.0             NaN         0.107143             NaN
# 12X372              6.0             NaN         0.085714             NaN
# 10X254             13.0             NaN         0.090909             NaN
# 30Q127             28.0             NaN         0.193103             NaN
# 23K644             12.0             NaN         0.137931             NaN
# 22K109             12.0             NaN         0.118812             NaN
# 09X313              9.0             NaN         0.085714             NaN
# 09X327             15.0             NaN         0.142857             NaN
# 84K730              7.0             NaN         0.148936             NaN
# 19K409             10.0             NaN         0.140845             NaN
# 84X492             11.0             NaN         0.095652             NaN
# 84K757             15.0             NaN         0.142857             NaN
# ...                 ...             ...              ...             ...
# 11X287             23.0             NaN         0.126374             NaN
# 23K668              6.0             NaN         0.127660             NaN
# 23K671             10.0             NaN         0.144928             NaN
# 17K352              9.0             NaN         0.125000             NaN
# 09X241             13.0             NaN         0.158537             NaN
# 08X131             22.0             NaN         0.138365             NaN
# 07X005              8.0             NaN         0.112676             NaN
# 24Q077             61.0             NaN         0.176812             NaN
# 10X368             27.0             NaN         0.174194             NaN
# 12X271             14.0             NaN         0.159091             NaN
# 12X129             29.0             NaN         0.171598             NaN
# 17K484              7.0             NaN         0.152174             NaN
# 10X390             24.0             NaN         0.147239             NaN
# 07X031              9.0             NaN         0.115385             NaN
# 10X243             18.0             NaN         0.189474             NaN
# 19K661             24.0             NaN         0.192000             NaN
# 23K323             10.0             NaN         0.142857             NaN
# 08X448             19.0             NaN         0.157025             NaN
# 29Q116             10.0             NaN         0.158730             NaN
# 10X447             29.0             NaN         0.184713             NaN
# 22K078             35.0             NaN         0.174129             NaN
# 10X206              8.0             NaN         0.115942             NaN
# 18K211             36.0             NaN         0.194595             NaN
# 12X273             11.0             NaN         0.150685             NaN
# 28Q287             21.0             NaN         0.169355             NaN
# 08X376              9.0             NaN         0.191489             NaN
# 29Q355             17.0             NaN         0.166667             NaN
# 12X242             17.0             NaN         0.180851             NaN
# 27Q309             13.0             NaN         0.178082             NaN
# 27Q053             16.0             NaN         0.133333             NaN
# 10X045             46.0             NaN         0.178988             NaN
# 18K588             11.0             NaN         0.183333             NaN
# 16K308              8.0             NaN         0.140351             NaN
# 17K246             24.0             NaN         0.157895             NaN
# 09X022             24.0             NaN         0.161074             NaN
# 84X177             16.0             NaN         0.181818             NaN
# 08X467             21.0             NaN         0.182609             NaN
# 12X318             18.0             NaN         0.178218             NaN
# 11X355             24.0             NaN         0.181818             NaN
# 11X566             31.0             NaN         0.191358             NaN
# 12X214             28.0             NaN         0.185430             NaN
# 09X339             27.0             NaN         0.156977             NaN
# 19K364             21.0             NaN         0.190909             NaN
# 12X384             10.0             NaN         0.138889             NaN
# 09X325             16.0             NaN         0.139130             NaN
# 17K722             13.0             NaN         0.180556             NaN
# 23K284              9.0             NaN         0.180000             NaN
# 19K654             15.0             NaN         0.168539             NaN
# 19K663             12.0             NaN         0.190476             NaN
# 09X323             29.0             NaN         0.183544             NaN
#
#         Diff Cnt (min)
# DBN
# 32K162      -18.775973
# 84X482      -15.439358
# 29Q259      -11.690162
# 10X037      -10.970738
# 09X004      -11.577633
# 07X221      -12.370560
# 19K171      -16.897668
# 19K422       -7.857126
# 09X219       -9.597713
# 19K404       -8.098963
# 08X302      -15.308105
# 12X211       -8.037046
# 10X225       -5.735446
# 15K448       -6.375206
# 32K291       -8.313207
# 29Q356       -8.766665
# 32K349       -6.879076
# 29Q147       -8.171911
# 10X391      -15.869982
# 14K050       -6.515247
# 84R067      -12.947175
# 24Q311      -13.069025
# 19K760       -8.299227
# 24Q061      -71.869496
# 19K662      -10.117666
# 07X296       -5.115261
# 29Q138       -7.723252
# 09X303      -11.591498
# 13K266       -5.748175
# 14K586       -4.545023
# 09X505       -8.589885
# 12X217       -5.960104
# 16K057       -6.204211
# 27Q105       -5.038652
# 32K562       -6.878046
# 12X341       -4.478005
# 07X223      -10.221602
# 15K136      -11.596420
# 07X298       -5.728243
# 12X372       -3.836510
# 10X254       -8.104925
# 30Q127      -14.187977
# 23K644       -6.709194
# 22K109       -6.843605
# 09X313       -5.349961
# 09X327       -7.960197
# 84K730       -3.585487
# 19K409       -5.189363
# 84X492       -5.839040
# 84K757       -7.335660
# ...                ...
# 11X287       -7.621792
# 23K668       -1.969309
# 23K671       -3.045084
# 17K352       -2.541327
# 09X241       -3.290193
# 08X131       -5.573316
# 07X005       -2.096791
# 24Q077      -14.375185
# 10X368       -6.248850
# 12X271       -3.260048
# 12X129       -6.106556
# 17K484       -1.429208
# 10X390       -4.722124
# 07X031       -1.739995
# 10X243       -2.901384
# 19K661       -3.758595
# 23K323       -1.434279
# 08X448       -2.334370
# 29Q116       -1.088680
# 10X447       -2.968147
# 22K078       -3.554317
# 10X206       -0.862513
# 18K211       -3.490795
# 12X273       -1.080514
# 28Q287       -1.739874
# 08X376       -0.704804
# 29Q355       -0.770532
# 12X242       -0.121721
# 27Q309        0.092417
# 27Q053        0.156321
# 10X045        1.292650
# 18K588        0.324312
# 16K308        0.266929
# 17K246        0.862219
# 09X022        0.890296
# 84X177        0.688693
# 08X467        0.944806
# 12X318        1.174395
# 11X355        1.585697
# 11X566        2.047808
# 12X214        2.199163
# 09X339        2.530724
# 19K364        2.627178
# 12X384        1.335393
# 09X325        2.382641
# 17K722        2.283405
# 23K284        1.792743
# 19K654        3.078293
# 19K663        2.425076
# 09X323        8.189551
#
# [115 rows x 28 columns]

# %%
a.loc['32K162']
# Out:
# School Name                               J.H.S. 162 The Willoughby
# Charter School?                                                   0
# Borough                                                    brooklyn
# Latitude                                                    40.7068
# Longitude                                                  -73.9196
# Percent Asian                                                 0.024
# Percent Black                                                 0.035
# Percent Hispanic                                              0.908
# Percent White                                                 0.026
# Percent Other                                                 0.007
# Percent English Language Learners                             0.195
# Percent Students with Disabilities                            0.266
# Percent of Students Chronically Absent                        0.299
# Economic Need Index                                           0.823
# Mean Scale Score - ELA                                      293.426
# % Level 2 - ELA                                              52.027
# % Level 3 - ELA                                             16.2162
# % Level 4 - ELA                                            0.675676
# Mean Scale Score - Math                                      286.28
# % Level 2 - Math                                                 34
# % Level 3 - Math                                            8.66667
# % Level 4 - Math                                            1.33333
# # Students in HS Admissions                                     161
# # SHSAT Testers                                                   8
# # SHSAT Offers                                                  NaN
# % SHSAT Testers                                           0.0496894
# % SHSAT Offers                                                  NaN
# Diff Cnt (min)                                              -18.776
# Name: 32K162, dtype: object

# %% [markdown]
# ## Pandas format

# %%
format_dict = {
    'logit': '{:.2f}',
    'pct':   '{:.0%}',
    'cnt':   '{:.0f}',
}
table.head(10).style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_e859a436_9676_11e8_8211_c83a35ccb783" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >logit</th>
#         <th class="col_heading level0 col1" >pct</th>
#         <th class="col_heading level0 col2" >cnt</th>
#     </tr>    <tr>
#         <th class="index_name level0" >DBN</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_e859a436_9676_11e8_8211_c83a35ccb783level0_row0" class="row_heading level0 row0" >01M034</th>
#         <td id="T_e859a436_9676_11e8_8211_c83a35ccb783row0_col0" class="data row0 col0" >-2.16</td>
#         <td id="T_e859a436_9676_11e8_8211_c83a35ccb783row0_col1" class="data row0 col1" >10%</td>
#         <td id="T_e859a436_9676_11e8_8211_c83a35ccb783row0_col2" class="data row0 col2" >6</td>
#     </tr>    <tr>
#         <th id="T_e859a436_9676_11e8_8211_c83a35ccb783level0_row1" class="row_heading level0 row1" >01M140</th>
#         <td id="T_e859a436_9676_11e8_8211_c83a35ccb783row1_col0" class="data row1 col0" >-2.32</td>
#         <td id="T_e859a436_9676_11e8_8211_c83a35ccb783row1_col1" class="data row1 col1" >9%</td>
#         <td id="T_e859a436_9676_11e8_8211_c83a35ccb783row1_col2" class="data row1 col2" >6</td>
#     </tr>    <tr>
#         <th id="T_e859a436_9676_11e8_8211_c83a35ccb783level0_row2" class="row_heading level0 row2" >01M184</th>
#         <td id="T_e859a436_9676_11e8_8211_c83a35ccb783row2_col0" class="data row2 col0" >1.16</td>
#         <td id="T_e859a436_9676_11e8_8211_c83a35ccb783row2_col1" class="data row2 col1" >76%</td>
#         <td id="T_e859a436_9676_11e8_8211_c83a35ccb783row2_col2" class="data row2 col2" >67</td>
#     </tr>    <tr>
#         <th id="T_e859a436_9676_11e8_8211_c83a35ccb783level0_row3" class="row_heading level0 row3" >01M301</th>
#         <td id="T_e859a436_9676_11e8_8211_c83a35ccb783row3_col0" class="data row3 col0" >-1.29</td>
#         <td id="T_e859a436_9676_11e8_8211_c83a35ccb783row3_col1" class="data row3 col1" >22%</td>
#         <td id="T_e859a436_9676_11e8_8211_c83a35ccb783row3_col2" class="data row3 col2" >11</td>
#     </tr>    <tr>
#         <th id="T_e859a436_9676_11e8_8211_c83a35ccb783level0_row4" class="row_heading level0 row4" >01M332</th>
#         <td id="T_e859a436_9676_11e8_8211_c83a35ccb783row4_col0" class="data row4 col0" >-1.44</td>
#         <td id="T_e859a436_9676_11e8_8211_c83a35ccb783row4_col1" class="data row4 col1" >19%</td>
#         <td id="T_e859a436_9676_11e8_8211_c83a35ccb783row4_col2" class="data row4 col2" >13</td>
#     </tr>    <tr>
#         <th id="T_e859a436_9676_11e8_8211_c83a35ccb783level0_row5" class="row_heading level0 row5" >01M378</th>
#         <td id="T_e859a436_9676_11e8_8211_c83a35ccb783row5_col0" class="data row5 col0" >-1.40</td>
#         <td id="T_e859a436_9676_11e8_8211_c83a35ccb783row5_col1" class="data row5 col1" >20%</td>
#         <td id="T_e859a436_9676_11e8_8211_c83a35ccb783row5_col2" class="data row5 col2" >19</td>
#     </tr>    <tr>
#         <th id="T_e859a436_9676_11e8_8211_c83a35ccb783level0_row6" class="row_heading level0 row6" >01M450</th>
#         <td id="T_e859a436_9676_11e8_8211_c83a35ccb783row6_col0" class="data row6 col0" >-1.58</td>
#         <td id="T_e859a436_9676_11e8_8211_c83a35ccb783row6_col1" class="data row6 col1" >17%</td>
#         <td id="T_e859a436_9676_11e8_8211_c83a35ccb783row6_col2" class="data row6 col2" >16</td>
#     </tr>    <tr>
#         <th id="T_e859a436_9676_11e8_8211_c83a35ccb783level0_row7" class="row_heading level0 row7" >01M539</th>
#         <td id="T_e859a436_9676_11e8_8211_c83a35ccb783row7_col0" class="data row7 col0" >2.53</td>
#         <td id="T_e859a436_9676_11e8_8211_c83a35ccb783row7_col1" class="data row7 col1" >93%</td>
#         <td id="T_e859a436_9676_11e8_8211_c83a35ccb783row7_col2" class="data row7 col2" >126</td>
#     </tr>    <tr>
#         <th id="T_e859a436_9676_11e8_8211_c83a35ccb783level0_row8" class="row_heading level0 row8" >01M839</th>
#         <td id="T_e859a436_9676_11e8_8211_c83a35ccb783row8_col0" class="data row8 col0" >0.10</td>
#         <td id="T_e859a436_9676_11e8_8211_c83a35ccb783row8_col1" class="data row8 col1" >52%</td>
#         <td id="T_e859a436_9676_11e8_8211_c83a35ccb783row8_col2" class="data row8 col2" >66</td>
#     </tr>    <tr>
#         <th id="T_e859a436_9676_11e8_8211_c83a35ccb783level0_row9" class="row_heading level0 row9" >02M104</th>
#         <td id="T_e859a436_9676_11e8_8211_c83a35ccb783row9_col0" class="data row9 col0" >0.72</td>
#         <td id="T_e859a436_9676_11e8_8211_c83a35ccb783row9_col1" class="data row9 col1" >67%</td>
#         <td id="T_e859a436_9676_11e8_8211_c83a35ccb783row9_col2" class="data row9 col2" >260</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# ---

# %% [markdown]
# **TODO**
#
# Link this image with actual data
#
# ![](../data/output/shsat_offers_by_grade.png)
#
# ---

# %%
# percentage values
actual_pct = expit(outputs)
estimated_pct = expit(predictions)
residual_pct = actual_pct - estimated_pct

# absolute values (total count)
hs_admissions_counts = hs_admissions_counts.reindex(outputs.index)
actual_cnt = actual_pct * hs_admissions_counts
estimated_cnt = estimated_pct * hs_admissions_counts
residual_cnt = actual_cnt - estimated_cnt

# %%
reg_results = pd.DataFrame({
    'Actual #': actual_cnt,
    'Estimated #': np.round(estimated_cnt),
    'Difference #': np.round(residual_cnt),
    
    'Actual %': actual_pct,
    'Estimated %': estimated_pct,
    'Difference %': residual_pct,
})

# reg_results.loc[:, :'Difference #'] = reg_results.loc[:, :'Difference #'].applymap(lambda x: "{:.0f}".format(x))
# reg_results.loc[:, 'Actual %':] = reg_results.loc[:, 'Actual %':].applymap(lambda x: "{:.0%}".format(x))

reg_results.head()

# %%
d = pd.read_pickle('../data/process/schools2017.pkl')
d = d.loc[:, :'# Students in HS Admissions']
d = pd.concat([d, reg_results], axis=1, sort=True)
d.head()

# %%
d[(d['Borough'] == 'brooklyn') & (d['Actual %'] <= 0.15) & (d['Percent White'] < 0.2)].sort_values('Difference %')

# %% [markdown]
# ## One school example

# %%
d.loc['19K422']

# %% [markdown]
# This school was selected among the schools with the biggest difference in percentage. Characteristics:
#
# - Located on Brooklyn
# - Population mostly Black/Hispanic

# %% [markdown]
# Problem: Chronic Absenteeism seems to be being understimated. It is probably really correlated with other features, and we can't do much about it.
