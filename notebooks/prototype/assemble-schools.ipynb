# %% [markdown]
# # (prototype) Assemble schools
#
# In this kernel I will assemble schools info from the school years 2016-2017 and 2017-2018, regarding the class that took SHSAT on October 2017.
#
# ![](../data/keep/timeline.png)

# %%
import pandas as pd

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', None)

# %%
# !ls ../data/pre
# Out:
# middle_school_base.pkl		  school_locations.pkl	    shsat_table.pkl
# nyt_table.pkl			  schools2016.pkl	    test_results.pkl
# school_demographics_20162017.pkl  schools_demographics.pkl

# %%
locations = pd.read_pickle('../data/pre/school_locations.pkl')  # School Locations (2017-2018)
tests = pd.read_pickle('../data/pre/test_results.pkl')  # NYS Test Results (from 2013 to 2017)
shsat = pd.read_pickle('../data/pre/shsat_table.pkl')  # SHSAT Testers and Offers (2017-18)
demographics = pd.read_pickle('../data/pre/school_demographics_20162017.pkl')  # School Quality Report (2016-17)

# %%
locations.shape
# Out:
# (1822, 3)

# %%
tests.shape
# Out:
# (46305, 25)

# %%
shsat.shape  # these are our targets
# Out:
# (594, 5)

# %%
demographics.shape
# Out:
# (1269, 9)

# %% [markdown]
# # Prepare
#
# ## Tests DataFrame

# %%
tests = pd.read_pickle('../data/pre/test_results.pkl')  # NYS Test Results
tests = tests.reset_index()
tests = tests[(tests['Grade'] == 7) &
              (tests['Year'] == 2017)]
tests = tests.set_index('DBN')
tests.head()
# Out:
#        Grade  Year  Charter School?  Number Tested - ELA  \
# DBN
# 01M015     7  2017                0                  0.0
# 01M019     7  2017                0                  0.0
# 01M020     7  2017                0                  0.0
# 01M034     7  2017                0                 54.0
# 01M063     7  2017                0                  0.0
#
#         Mean Scale Score - ELA  # Level 1 - ELA  % Level 1 - ELA  \
# DBN
# 01M015                     NaN              NaN              NaN
# 01M019                     NaN              NaN              NaN
# 01M020                     NaN              NaN              NaN
# 01M034                298.2778              9.0         16.66667
# 01M063                     NaN              NaN              NaN
#
#         # Level 2 - ELA  % Level 2 - ELA  # Level 3 - ELA  % Level 3 - ELA  \
# DBN
# 01M015              NaN              NaN              NaN              NaN
# 01M019              NaN              NaN              NaN              NaN
# 01M020              NaN              NaN              NaN              NaN
# 01M034             32.0         59.25926             12.0         22.22222
# 01M063              NaN              NaN              NaN              NaN
#
#         # Level 4 - ELA  % Level 4 - ELA  # Level 3+4 - ELA  \
# DBN
# 01M015              NaN              NaN                NaN
# 01M019              NaN              NaN                NaN
# 01M020              NaN              NaN                NaN
# 01M034              1.0         1.851852               13.0
# 01M063              NaN              NaN                NaN
#
#         % Level 3+4 - ELA  Number Tested - Math  Mean Scale Score - Math  \
# DBN
# 01M015                NaN                   0.0                      NaN
# 01M019                NaN                   0.0                      NaN
# 01M020                NaN                   0.0                      NaN
# 01M034           24.07407                  52.0                 285.9423
# 01M063                NaN                   0.0                      NaN
#
#         # Level 1 - Math  % Level 1 - Math  # Level 2 - Math  \
# DBN
# 01M015               NaN               NaN               NaN
# 01M019               NaN               NaN               NaN
# 01M020               NaN               NaN               NaN
# 01M034              27.0          51.92308              18.0
# 01M063               NaN               NaN               NaN
#
#         % Level 2 - Math  # Level 3 - Math  % Level 3 - Math  \
# DBN
# 01M015               NaN               NaN               NaN
# 01M019               NaN               NaN               NaN
# 01M020               NaN               NaN               NaN
# 01M034          34.61538               7.0          13.46154
# 01M063               NaN               NaN               NaN
#
#         # Level 4 - Math  % Level 4 - Math  # Level 3+4 - Math  \
# DBN
# 01M015               NaN               NaN                 NaN
# 01M019               NaN               NaN                 NaN
# 01M020               NaN               NaN                 NaN
# 01M034               0.0               0.0                 7.0
# 01M063               NaN               NaN                 NaN
#
#         % Level 3+4 - Math
# DBN
# 01M015                 NaN
# 01M019                 NaN
# 01M020                 NaN
# 01M034            13.46154
# 01M063                 NaN

# %%
tests = pd.read_pickle('../data/pre/test_results.pkl')  # NYS Test Results
tests = tests.reset_index()
tests = tests[(tests['Grade'] == 7) &
              (tests['Year'] == 2017)]
tests = tests.set_index('DBN')
tests = tests[[
    'Charter School?',
    'Mean Scale Score - ELA',
    '% Level 2 - ELA',
    '% Level 3 - ELA',
    '% Level 4 - ELA',
    'Mean Scale Score - Math',
    '% Level 2 - Math',
    '% Level 3 - Math',
    '% Level 4 - Math',
]]

tests.head()
# Out:
#         Charter School?  Mean Scale Score - ELA  % Level 2 - ELA  \
# DBN
# 01M015                0                     NaN              NaN
# 01M019                0                     NaN              NaN
# 01M020                0                     NaN              NaN
# 01M034                0                298.2778         59.25926
# 01M063                0                     NaN              NaN
#
#         % Level 3 - ELA  % Level 4 - ELA  Mean Scale Score - Math  \
# DBN
# 01M015              NaN              NaN                      NaN
# 01M019              NaN              NaN                      NaN
# 01M020              NaN              NaN                      NaN
# 01M034         22.22222         1.851852                 285.9423
# 01M063              NaN              NaN                      NaN
#
#         % Level 2 - Math  % Level 3 - Math  % Level 4 - Math
# DBN
# 01M015               NaN               NaN               NaN
# 01M019               NaN               NaN               NaN
# 01M020               NaN               NaN               NaN
# 01M034          34.61538          13.46154               0.0
# 01M063               NaN               NaN               NaN

# %%
tests.shape
# Out:
# (1323, 9)

# %% [markdown]
# # Join

# %%
joined = shsat.join(locations).join(tests).join(demographics)
joined['Percent Other'] = 1 - joined.loc[:, 'Percent Asian':'Percent White'].sum(axis=1, skipna=False)
joined.head()
# Out:
#         # Students in HS Admissions  # SHSAT Testers  # SHSAT Offers  \
# DBN
# 01M034                         58.0              6.0             NaN
# 01M140                         67.0              6.0             NaN
# 01M184                         88.0             67.0            23.0
# 01M188                         59.0              NaN             NaN
# 01M301                         51.0             11.0             NaN
#
#         % SHSAT Testers  % SHSAT Offers   Latitude  Longitude    Borough  \
# DBN
# 01M034         0.103448             NaN  40.726008 -73.975058  manhattan
# 01M140         0.089552             NaN  40.719148 -73.983769  manhattan
# 01M184         0.761364        0.261364  40.711125 -73.985438  manhattan
# 01M188              NaN             NaN  40.719888 -73.977380  manhattan
# 01M301         0.215686             NaN  40.730009 -73.984496  manhattan
#
#         Charter School?  Mean Scale Score - ELA  % Level 2 - ELA  \
# DBN
# 01M034              0.0                298.2778         59.25926
# 01M140              0.0                297.4545         60.00000
# 01M184              0.0                330.1358         20.98765
# 01M188              0.0                295.6667         45.09804
# 01M301              0.0                304.7073         46.34146
#
#         % Level 3 - ELA  % Level 4 - ELA  Mean Scale Score - Math  \
# DBN
# 01M034         22.22222         1.851852                 285.9423
# 01M140         21.81818         1.818182                 291.2456
# 01M184         39.50617        34.567900                 339.6988
# 01M188         15.68627         1.960784                 294.5000
# 01M301         31.70732         4.878049                 288.1951
#
#         % Level 2 - Math  % Level 3 - Math  % Level 4 - Math  \
# DBN
# 01M034          34.61538          13.46154          0.000000
# 01M140          38.59649          14.03509          0.000000
# 01M184          16.86747          28.91566         44.578310
# 01M188          46.15385          21.15385          0.000000
# 01M301          36.58537          12.19512          2.439024
#
#                                   School Name  Percent Asian  Percent Black  \
# DBN
# 01M034         P.S. 034 Franklin D. Roosevelt          0.053          0.297
# 01M140                 P.S. 140 Nathan Straus          0.044          0.121
# 01M184                   P.S. 184m Shuang Wen          0.697          0.044
# 01M188             P.S. 188 The Island School          0.019          0.320
# 01M301  Technology, Arts, and Sciences Studio          0.087          0.323
#
#         Percent Hispanic  Percent White  Percent English Language Learners  \
# DBN
# 01M034             0.614          0.030                              0.080
# 01M140             0.794          0.030                              0.124
# 01M184             0.124          0.085                              0.171
# 01M188             0.625          0.036                              0.154
# 01M301             0.496          0.055                              0.047
#
#         Percent Students with Disabilities  \
# DBN
# 01M034                               0.380
# 01M140                               0.338
# 01M184                               0.192
# 01M188                               0.332
# 01M301                               0.441
#
#         Percent of Students Chronically Absent  Economic Need Index  \
# DBN
# 01M034                                   0.305                0.872
# 01M140                                   0.395                0.853
# 01M184                                   0.041                0.560
# 01M188                                   0.369                0.938
# 01M301                                   0.382                0.746
#
#         Percent Other
# DBN
# 01M034          0.006
# 01M140          0.011
# 01M184          0.050
# 01M188          0.000
# 01M301          0.039

# %%
columns = [
    'School Name',
    'Charter School?',
    'Borough',
    'Latitude',
    'Longitude',
    
    'Percent Asian',
    'Percent Black',
    'Percent Hispanic',
    'Percent White',
    'Percent Other',
    
    'Percent English Language Learners',
    'Percent Students with Disabilities',
    'Percent of Students Chronically Absent',
    'Economic Need Index',
    
    'Mean Scale Score - ELA',
    '% Level 2 - ELA',
    '% Level 3 - ELA',
    '% Level 4 - ELA',
    'Mean Scale Score - Math',
    '% Level 2 - Math',
    '% Level 3 - Math',
    '% Level 4 - Math',
    
    '# Students in HS Admissions',
    '# SHSAT Testers',
    '# SHSAT Offers',
    '% SHSAT Testers',
    '% SHSAT Offers',
]
joined = joined[columns]
joined.head()
# Out:
#                                   School Name  Charter School?    Borough  \
# DBN
# 01M034         P.S. 034 Franklin D. Roosevelt              0.0  manhattan
# 01M140                 P.S. 140 Nathan Straus              0.0  manhattan
# 01M184                   P.S. 184m Shuang Wen              0.0  manhattan
# 01M188             P.S. 188 The Island School              0.0  manhattan
# 01M301  Technology, Arts, and Sciences Studio              0.0  manhattan
#
#          Latitude  Longitude  Percent Asian  Percent Black  Percent Hispanic  \
# DBN
# 01M034  40.726008 -73.975058          0.053          0.297             0.614
# 01M140  40.719148 -73.983769          0.044          0.121             0.794
# 01M184  40.711125 -73.985438          0.697          0.044             0.124
# 01M188  40.719888 -73.977380          0.019          0.320             0.625
# 01M301  40.730009 -73.984496          0.087          0.323             0.496
#
#         Percent White  Percent Other  Percent English Language Learners  \
# DBN
# 01M034          0.030          0.006                              0.080
# 01M140          0.030          0.011                              0.124
# 01M184          0.085          0.050                              0.171
# 01M188          0.036          0.000                              0.154
# 01M301          0.055          0.039                              0.047
#
#         Percent Students with Disabilities  \
# DBN
# 01M034                               0.380
# 01M140                               0.338
# 01M184                               0.192
# 01M188                               0.332
# 01M301                               0.441
#
#         Percent of Students Chronically Absent  Economic Need Index  \
# DBN
# 01M034                                   0.305                0.872
# 01M140                                   0.395                0.853
# 01M184                                   0.041                0.560
# 01M188                                   0.369                0.938
# 01M301                                   0.382                0.746
#
#         Mean Scale Score - ELA  % Level 2 - ELA  % Level 3 - ELA  \
# DBN
# 01M034                298.2778         59.25926         22.22222
# 01M140                297.4545         60.00000         21.81818
# 01M184                330.1358         20.98765         39.50617
# 01M188                295.6667         45.09804         15.68627
# 01M301                304.7073         46.34146         31.70732
#
#         % Level 4 - ELA  Mean Scale Score - Math  % Level 2 - Math  \
# DBN
# 01M034         1.851852                 285.9423          34.61538
# 01M140         1.818182                 291.2456          38.59649
# 01M184        34.567900                 339.6988          16.86747
# 01M188         1.960784                 294.5000          46.15385
# 01M301         4.878049                 288.1951          36.58537
#
#         % Level 3 - Math  % Level 4 - Math  # Students in HS Admissions  \
# DBN
# 01M034          13.46154          0.000000                         58.0
# 01M140          14.03509          0.000000                         67.0
# 01M184          28.91566         44.578310                         88.0
# 01M188          21.15385          0.000000                         59.0
# 01M301          12.19512          2.439024                         51.0
#
#         # SHSAT Testers  # SHSAT Offers  % SHSAT Testers  % SHSAT Offers
# DBN
# 01M034              6.0             NaN         0.103448             NaN
# 01M140              6.0             NaN         0.089552             NaN
# 01M184             67.0            23.0         0.761364        0.261364
# 01M188              NaN             NaN              NaN             NaN
# 01M301             11.0             NaN         0.215686             NaN

# %%
joined.isnull().mean()
# Out:
# School Name                               0.003367
# Charter School?                           0.003367
# Borough                                   0.000000
# Latitude                                  0.000000
# Longitude                                 0.000000
# Percent Asian                             0.003367
# Percent Black                             0.003367
# Percent Hispanic                          0.003367
# Percent White                             0.003367
# Percent Other                             0.000000
# Percent English Language Learners         0.003367
# Percent Students with Disabilities        0.003367
# Percent of Students Chronically Absent    0.020202
# Economic Need Index                       0.003367
# Mean Scale Score - ELA                    0.005051
# % Level 2 - ELA                           0.005051
# % Level 3 - ELA                           0.005051
# % Level 4 - ELA                           0.005051
# Mean Scale Score - Math                   0.010101
# % Level 2 - Math                          0.010101
# % Level 3 - Math                          0.010101
# % Level 4 - Math                          0.010101
# # Students in HS Admissions               0.001684
# # SHSAT Testers                           0.095960
# # SHSAT Offers                            0.796296
# % SHSAT Testers                           0.095960
# % SHSAT Offers                            0.796296
# dtype: float64

# %%
shsat.shape
# Out:
# (594, 5)

# %%
joined.shape
# Out:
# (594, 27)

# %% [markdown]
# # Missing info
#
# What are the schools with missing information?

# %%
joined[joined.loc[:, :'% Level 4 - Math'].isnull().any(axis=1)].sort_values('Mean Scale Score - ELA', ascending=False)
# Out:
#                                               School Name  Charter School?  \
# DBN
# 84M482          Success Academy Charter School - Harlem 5              1.0
# 17K590            Medgar Evers College Preparatory School              0.0
# 84X494           Success Academy Charter School - Bronx 2              1.0
# 84M384          Success Academy Charter School - Harlem 2              1.0
# 84X493           Success Academy Charter School - Bronx 1              1.0
# 84M351          Success Academy Charter School - Harlem 1              1.0
# 84M385          Success Academy Charter School - Harlem 3              1.0
# 84M386          Success Academy Charter School - Harlem 4              1.0
# 02M347  The 47 American Sign Language & English Lower ...              0.0
# 29Q283  Preparatory Academy for Writers: A College Boa...              0.0
# 84K780            Brooklyn East Collegiate Charter School              1.0
# 84K803                        Brooklyn LABÿCharter School              1.0
# 84X460                          Atmosphere Charter School              1.0
# 07X584                                                NaN              NaN
# 84M337                                                NaN              NaN
# 84X233              Family Life Academy Charter School II              1.0
#
#           Borough   Latitude  Longitude  Percent Asian  Percent Black  \
# DBN
# 84M482  manhattan  40.820216 -73.944551          0.009          0.675
# 17K590   brooklyn  40.666790 -73.951823          0.036          0.870
# 84X494      bronx  40.835934 -73.904970          0.011          0.634
# 84M384  manhattan  40.805653 -73.935461          0.016          0.694
# 84X493      bronx  40.813681 -73.925995          0.013          0.545
# 84M351  manhattan  40.802649 -73.948088          0.010          0.737
# 84M385  manhattan  40.785107 -73.942154          0.013          0.601
# 84M386  manhattan  40.801573 -73.955583          0.009          0.660
# 02M347  manhattan  40.738374 -73.981329          0.014          0.236
# 29Q283     queens  40.669030 -73.757744          0.022          0.868
# 84K780   brooklyn  40.678554 -73.966333          0.017          0.780
# 84K803   brooklyn  40.697262 -73.986016          0.017          0.738
# 84X460  manhattan  40.875161 -73.910426          0.016          0.237
# 07X584      bronx  40.814857 -73.912038            NaN            NaN
# 84M337  manhattan  40.785559 -73.940919            NaN            NaN
# 84X233      bronx  40.811562 -73.925416          0.007          0.279
#
#         Percent Hispanic  Percent White  Percent Other  \
# DBN
# 84M482             0.281          0.009          0.026
# 17K590             0.039          0.003          0.052
# 84X494             0.339          0.011          0.005
# 84M384             0.263          0.019          0.008
# 84X493             0.420          0.004          0.018
# 84M351             0.204          0.014          0.035
# 84M385             0.343          0.017          0.026
# 84M386             0.281          0.019          0.031
# 02M347             0.557          0.143          0.050
# 29Q283             0.071          0.005          0.034
# 84K780             0.069          0.014          0.120
# 84K803             0.188          0.031          0.026
# 84X460             0.735          0.008          0.004
# 07X584               NaN            NaN            NaN
# 84M337               NaN            NaN            NaN
# 84X233             0.707          0.003          0.004
#
#         Percent English Language Learners  Percent Students with Disabilities  \
# DBN
# 84M482                              0.059                               0.211
# 17K590                              0.000                               0.010
# 84X494                              0.061                               0.142
# 84M384                              0.026                               0.192
# 84X493                              0.052                               0.144
# 84M351                              0.037                               0.183
# 84M385                              0.034                               0.164
# 84M386                              0.041                               0.226
# 02M347                              0.064                               0.593
# 29Q283                              0.027                               0.181
# 84K780                              0.014                               0.165
# 84K803                              0.015                               0.284
# 84X460                              0.133                               0.257
# 07X584                                NaN                                 NaN
# 84M337                                NaN                                 NaN
# 84X233                              0.133                               0.129
#
#         Percent of Students Chronically Absent  Economic Need Index  \
# DBN
# 84M482                                     NaN                0.721
# 17K590                                   0.062                0.440
# 84X494                                     NaN                0.781
# 84M384                                     NaN                0.727
# 84X493                                     NaN                0.786
# 84M351                                     NaN                0.701
# 84M385                                     NaN                0.723
# 84M386                                     NaN                0.692
# 02M347                                   0.268                0.724
# 29Q283                                   0.090                0.381
# 84K780                                     NaN                0.585
# 84K803                                     NaN                0.654
# 84X460                                     NaN                0.729
# 07X584                                     NaN                  NaN
# 84M337                                     NaN                  NaN
# 84X233                                   0.279                0.814
#
#         Mean Scale Score - ELA  % Level 2 - ELA  % Level 3 - ELA  \
# DBN
# 84M482                344.0862         6.896552         44.82759
# 17K590                342.7000        14.444440         31.11111
# 84X494                341.8485         3.030303         56.06061
# 84M384                337.8611         9.722222         52.77778
# 84X493                336.6909        10.909090         58.18182
# 84M351                331.1308        15.887850         62.61682
# 84M385                330.0610        17.073170         64.63415
# 84M386                328.3676        22.058820         52.94118
# 02M347                319.8333        33.333330         50.00000
# 29Q283                312.9556        40.000000         42.22222
# 84K780                308.7195        50.000000         28.04878
# 84K803                308.5766        54.054050         24.32432
# 84X460                301.5197        52.755910         24.40945
# 07X584                     NaN              NaN              NaN
# 84M337                     NaN              NaN              NaN
# 84X233                     NaN              NaN              NaN
#
#         % Level 4 - ELA  Mean Scale Score - Math  % Level 2 - Math  \
# DBN
# 84M482        48.275860                 353.3276          1.724138
# 17K590        54.444440                      NaN               NaN
# 84X494        40.909090                 359.6269          0.000000
# 84M384        37.500000                 346.3611          8.333333
# 84X493        30.909090                 351.1273          3.636364
# 84M351        21.495330                 339.7664          9.345794
# 84M385        18.292680                 342.6173         12.345680
# 84M386        23.529410                 339.2647         13.235290
# 02M347        16.666670                      NaN               NaN
# 29Q283         6.666667                      NaN               NaN
# 84K780         8.536585                 315.7654         41.975310
# 84K803         8.108108                 297.6606         35.779820
# 84X460         3.937008                 287.2222         27.777780
# 07X584              NaN                      NaN               NaN
# 84M337              NaN                      NaN               NaN
# 84X233              NaN                      NaN               NaN
#
#         % Level 3 - Math  % Level 4 - Math  # Students in HS Admissions  \
# DBN
# 84M482          43.10345         55.172410                         59.0
# 17K590               NaN               NaN                         88.0
# 84X494          28.35821         71.641790                         65.0
# 84M384          43.05556         48.611110                         69.0
# 84X493          41.81818         54.545450                         47.0
# 84M351          49.53271         37.383180                        101.0
# 84M385          48.14815         38.271600                         69.0
# 84M386          36.76471         44.117650                         66.0
# 02M347               NaN               NaN                          9.0
# 29Q283               NaN               NaN                         43.0
# 84K780          34.56790          7.407407                         87.0
# 84K803          19.26606          4.587156                        137.0
# 84X460          15.87302          4.761905                        126.0
# 07X584               NaN               NaN                        106.0
# 84M337               NaN               NaN                          NaN
# 84X233               NaN               NaN                         50.0
#
#         # SHSAT Testers  # SHSAT Offers  % SHSAT Testers  % SHSAT Offers
# DBN
# 84M482             40.0             NaN         0.677966             NaN
# 17K590             15.0             NaN         0.170455             NaN
# 84X494             36.0             6.0         0.553846        0.092308
# 84M384             37.0             NaN         0.536232             NaN
# 84X493             30.0             NaN         0.638298             NaN
# 84M351             35.0             NaN         0.346535             NaN
# 84M385             29.0             NaN         0.420290             NaN
# 84M386             20.0             NaN         0.303030             NaN
# 02M347              NaN             NaN              NaN             NaN
# 29Q283             10.0             NaN         0.232558             NaN
# 84K780             54.0             NaN         0.620690             NaN
# 84K803             40.0             NaN         0.291971             NaN
# 84X460             43.0             NaN         0.341270             NaN
# 07X584             10.0             NaN         0.094340             NaN
# 84M337              NaN             NaN              NaN             NaN
# 84X233             30.0             NaN         0.600000             NaN

# %% [markdown]
# We examine them later. By now, we drop them.
