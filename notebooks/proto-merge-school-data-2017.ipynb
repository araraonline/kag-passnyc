# %% [markdown]
# # Merge school data from 2017
#
# Let's assemble all the school data we have from 2017 into one bigass DataFrame. Mainly, it will have:
#
# - School basic characteristics (#students, location, ethnic composition, etc.)
# - 7th graders results for NYS ELA and Math tests (these are the guys that will take SHSAT this same year)
# - 8th graders number of SHSAT applicants
#
# Some information that may be useful (from any source):
#
# - School Name
# - Neighborhood
# - Borough
# - Charter School
# - Community School

# %%
# !ls ../data/pre
# Out:
# nyt_table.pkl  schools2016.pkl	schools_demographics.pkl  test_results.pkl

# %%
import pandas as pd

basic = pd.read_pickle('../data/pre/schools_demographics.pkl')
results = pd.read_pickle('../data/pre/test_results.pkl')
applicants = pd.read_pickle('../data/pre/nyt_table.pkl')

# %% [markdown]
# ## Basic DataFrame

# %%
basic.head()
# Out:
#       DBN                School Name     Year  Total Enrollment  \
# 0  01M015  P.S. 015 Roberto Clemente  2013-14               190
# 1  01M015  P.S. 015 Roberto Clemente  2014-15               183
# 2  01M015  P.S. 015 Roberto Clemente  2015-16               176
# 3  01M015  P.S. 015 Roberto Clemente  2016-17               178
# 4  01M015  P.S. 015 Roberto Clemente  2017-18               190
#
#    Grade PK (Half Day & Full Day)  Grade K  Grade 1  Grade 2  Grade 3  \
# 0                              26       39       39       21       16
# 1                              18       27       47       31       19
# 2                              14       32       33       39       23
# 3                              17       28       33       27       31
# 4                              17       28       32       33       23
#
#    Grade 4         ...           % Multiple Race Categories Not Represented  \
# 0       26         ...                                             0.010526
# ...

# %%
basic = basic[basic['Year'] == '2017-18']
basic.head()
# Out:
#        DBN                     School Name     Year  Total Enrollment  \
# 4   01M015       P.S. 015 Roberto Clemente  2017-18               190
# 9   01M019             P.S. 019 Asher Levy  2017-18               257
# 14  01M020            P.S. 020 Anna Silver  2017-18               497
# 19  01M034  P.S. 034 Franklin D. Roosevelt  2017-18               333
# 24  01M063       The STAR Academy - P.S.63  2017-18               203
#
#     Grade PK (Half Day & Full Day)  Grade K  Grade 1  Grade 2  Grade 3  \
# 4                               17       28       32       33       23
# 9                               13       34       38       42       46
# 14                              34       71       82       69       89
# 19                              13       25       18       22       47
# 24                              26       40       29       36       22
#
#     Grade 4         ...           % Multiple Race Categories Not Represented  \
# ...

# %%
columns = [
    'DBN',
    'School Name',
    'Grade 8',
    '% Female',
    '% Male',
    '% Asian',
    '% Black',
    '% Hispanic',
    '% Multiple Race Categories Not Represented',
    '% White',
    '% Students with Disabilities',
    '% English Language Learners',
    '% Poverty',
    'Economic Need Index'
]

basic = basic[columns]
basic.head()
# Out:
#        DBN                     School Name  Grade 8  % Female    % Male  \
# 4   01M015       P.S. 015 Roberto Clemente        0  0.521053  0.478947
# 9   01M019             P.S. 019 Asher Levy        0  0.443580  0.556420
# 14  01M020            P.S. 020 Anna Silver        0  0.490946  0.509054
# 19  01M034  P.S. 034 Franklin D. Roosevelt       58  0.450450  0.549550
# 24  01M063       The STAR Academy - P.S.63        0  0.492611  0.507389
#
#      % Asian   % Black  % Hispanic  \
# 4   0.105263  0.273684    0.578947
# 9   0.089494  0.190661    0.645914
# 14  0.295775  0.102616    0.531187
# 19  0.033033  0.318318    0.612613
# 24  0.029557  0.182266    0.630542
#
#     % Multiple Race Categories Not Represented   % White  \
# 4                                     0.010526  0.031579
# 9                                     0.011673  0.062257
# 14                                    0.038229  0.032193
# 19                                    0.009009  0.027027
# ...

# %%
basic = basic[basic['Grade 8'] > 0]
basic.head()
# Out:
#        DBN                            School Name  Grade 8  % Female  \
# 19  01M034         P.S. 034 Franklin D. Roosevelt       58  0.450450
# 44  01M140                 P.S. 140 Nathan Straus       66  0.490566
# 54  01M184                   P.S. 184m Shuang Wen       87  0.498538
# 59  01M188             P.S. 188 The Island School       60  0.427252
# 69  01M301  Technology, Arts, and Sciences Studio       51  0.452830
#
#       % Male   % Asian   % Black  % Hispanic  \
# 19  0.549550  0.033033  0.318318    0.612613
# 44  0.509434  0.056604  0.123989    0.787062
# 54  0.501462  0.694444  0.036550    0.134503
# 59  0.572748  0.018476  0.293303    0.660508
# 69  0.547170  0.037736  0.320755    0.547170
#
#     % Multiple Race Categories Not Represented   % White  \
# 19                                    0.009009  0.027027
# 44                                    0.005391  0.026954
# 54                                    0.061404  0.073099
# ...

# %%
basic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 648 entries, 19 to 8961
# Data columns (total 14 columns):
# DBN                                           648 non-null object
# School Name                                   648 non-null object
# Grade 8                                       648 non-null int64
# % Female                                      648 non-null float64
# % Male                                        648 non-null float64
# % Asian                                       648 non-null float64
# % Black                                       648 non-null float64
# % Hispanic                                    648 non-null float64
# % Multiple Race Categories Not Represented    648 non-null float64
# % White                                       648 non-null float64
# % Students with Disabilities                  648 non-null float64
# % English Language Learners                   648 non-null float64
# ...

# %% [markdown]
# ## Results DataFrame

# %%
results.head()
# Out:
#       DBN              School Name Grade  Year  Number Tested - ELA  \
# 0  01M015  PS 015 ROBERTO CLEMENTE     3  2013                   27
# 1  01M015  PS 015 ROBERTO CLEMENTE     3  2014                   18
# 2  01M015  PS 015 ROBERTO CLEMENTE     3  2015                   16
# 3  01M015  PS 015 ROBERTO CLEMENTE     3  2016                   20
# 4  01M015  PS 015 ROBERTO CLEMENTE     3  2017                   27
#
#    Mean Scale Score - ELA  # Level 1 - ELA  % Level 1 - ELA  # Level 2 - ELA  \
# 0                289.2963             14.0         51.85185             11.0
# 1                285.1111             10.0         55.55556              8.0
# 2                281.8125              9.0         56.25000              5.0
# 3                292.5000             10.0         50.00000              6.0
# 4                302.3704             10.0         37.03704              8.0
#
#    % Level 2 - ELA         ...          # Level 1 - Math  % Level 1 - Math  \
# ...

# %%
results = results[(results['Grade'] == 7) &
                  (results['Year'] == 2017)]
results.head()
# Out:
#         DBN                          School Name Grade  Year  \
# 84   01M034          PS 034 FRANKLIN D ROOSEVELT     7  2017
# 215  01M140                 PS 140 NATHAN STRAUS     7  2017
# 270  01M184                   PS 184M SHUANG WEN     7  2017
# 305  01M188             PS 188 THE ISLAND SCHOOL     7  2017
# 340  01M301  TECHNOLOGY ARTS AND SCIENCES STUDIO     7  2017
#
#      Number Tested - ELA  Mean Scale Score - ELA  # Level 1 - ELA  \
# 84                    54                298.2778              9.0
# 215                   55                297.4545              9.0
# 270                   81                330.1358              4.0
# 305                   51                295.6667             19.0
# 340                   41                304.7073              7.0
#
#      % Level 1 - ELA  # Level 2 - ELA  % Level 2 - ELA         ...          \
# 84         16.666670             32.0         59.25926         ...
# ...

# %%
columns = [
    'DBN',
    'Charter School',
    'Number Tested - ELA',
    'Mean Scale Score - ELA',
    '# Level 1 - ELA',
    '% Level 1 - ELA',
    '# Level 2 - ELA',
    '% Level 2 - ELA',
    '# Level 3 - ELA',
    '% Level 3 - ELA',
    '# Level 4 - ELA',
    '% Level 4 - ELA',
    '# Level 3+4 - ELA',
    '% Level 3+4 - ELA',
    'Number Tested - Math',
    'Mean Scale Score - Math',
    '# Level 1 - Math',
    '% Level 1 - Math',
    '# Level 2 - Math',
    '% Level 2 - Math',
    '# Level 3 - Math',
    '% Level 3 - Math',
    '# Level 4 - Math',
    '% Level 4 - Math',
    '# Level 3+4 - Math',
    '% Level 3+4 - Math'
]
results = results[columns]

# %%
results.head()
# Out:
#         DBN  Charter School  Number Tested - ELA  Mean Scale Score - ELA  \
# 84   01M034               0                   54                298.2778
# 215  01M140               0                   55                297.4545
# 270  01M184               0                   81                330.1358
# 305  01M188               0                   51                295.6667
# 340  01M301               0                   41                304.7073
#
#      # Level 1 - ELA  % Level 1 - ELA  # Level 2 - ELA  % Level 2 - ELA  \
# 84               9.0        16.666670             32.0         59.25926
# 215              9.0        16.363640             33.0         60.00000
# 270              4.0         4.938272             17.0         20.98765
# 305             19.0        37.254900             23.0         45.09804
# 340              7.0        17.073170             19.0         46.34146
#
#      # Level 3 - ELA  % Level 3 - ELA         ...          # Level 1 - Math  \
# ...

# %%
results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 600 entries, 84 to 27528
# Data columns (total 26 columns):
# DBN                        600 non-null object
# Charter School             600 non-null int64
# Number Tested - ELA        600 non-null int64
# Mean Scale Score - ELA     600 non-null float64
# # Level 1 - ELA            600 non-null float64
# % Level 1 - ELA            600 non-null float64
# # Level 2 - ELA            600 non-null float64
# % Level 2 - ELA            600 non-null float64
# # Level 3 - ELA            600 non-null float64
# % Level 3 - ELA            600 non-null float64
# # Level 4 - ELA            600 non-null float64
# % Level 4 - ELA            600 non-null float64
# # Level 3+4 - ELA          600 non-null float64
# % Level 3+4 - ELA          600 non-null float64
# Number Tested - Math       600 non-null int64
# Mean Scale Score - Math    599 non-null float64
# # Level 1 - Math           599 non-null float64
# ...

# %% [markdown]
# ## Applicants DataFrame

# %%
applicants.head()
# Out:
#       DBN       school_name_number  \
# 0  20K187  Intermediate School 187
# 1  21K239  Intermediate School 239
# 2  03M054    Junior High School 54
# 3  15K051          Midde School 51
# 4  02M312                      NaN
#
#                                  school_name_details    borough  testers  \
# 0                       The Christa McAuliffe School   Brooklyn    251.0
# 1  The Mark Twain Intermediate School for the Gif...   Brooklyn    336.0
# 2                    The Booker T. Washington School  Manhattan    257.0
# 3                       The William Alexander School   Brooklyn    280.0
# 4  New York City Lab Middle School for Collaborat...  Manhattan    163.0
#
#    offers  offers_per_student  pct_hispanic_black
# 0   205.0                0.75                0.08
# 1   196.0                0.46                0.13
# 2   150.0                0.53                0.23
# 3   122.0                0.33                0.28
# 4   113.0                0.62                0.08

# %%
columns = [
    'DBN',
    'borough',
    'testers',
]
applicants = applicants[columns]
applicants.head()
# Out:
#       DBN    borough  testers
# 0  20K187   Brooklyn    251.0
# 1  21K239   Brooklyn    336.0
# 2  03M054  Manhattan    257.0
# 3  15K051   Brooklyn    280.0
# 4  02M312  Manhattan    163.0

# %% [markdown]
# ## Joining everything
#
# Let's join all schools characteristics.

# %%
basic.DBN.nunique()
# Out:
# 648

# %%
basic.shape
# Out:
# (648, 14)

# %%
results.DBN.nunique()
# Out:
# 600

# %%
results.shape
# Out:
# (600, 26)

# %%
applicants.DBN.nunique()
# Out:
# 589

# %%
applicants.shape
# Out:
# (589, 3)

# %% [markdown]
# As you can see, the amount of schools present keeps decreasing... (and it is much lower than the original 1.27k from the PASSNYC dataset)
#
# This needs to be addressed further (but not now).

# %%
d1 = basic.set_index('DBN')
d2 = results.set_index('DBN')
d3 = applicants.set_index('DBN')

df = d1.join(d2, how='inner').join(d3, how='inner')
df.shape
# Out:
# (578, 40)

# %% [markdown]
# We lost 11 schools.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 578 entries, 01M034 to 84X717
# Data columns (total 40 columns):
# School Name                                   578 non-null object
# Grade 8                                       578 non-null int64
# % Female                                      578 non-null float64
# % Male                                        578 non-null float64
# % Asian                                       578 non-null float64
# % Black                                       578 non-null float64
# % Hispanic                                    578 non-null float64
# % Multiple Race Categories Not Represented    578 non-null float64
# % White                                       578 non-null float64
# % Students with Disabilities                  578 non-null float64
# % English Language Learners                   578 non-null float64
# % Poverty                                     578 non-null float64
# ...

# %% [markdown]
# All okay, let's organize the columns...

# %%
new_names = {
    'borough': 'Borough',
    'testers': '# SHSAT Testers',
    'Grade 8': '# Students Grade 8'
}
df = df.rename(columns=new_names)

# %%
columns = [
    'School Name',
    'Borough',
    'Charter School',
    'Economic Need Index',
    '% Female',
    '% Male',
    '% Asian',
    '% Black',
    '% Hispanic',
    '% Multiple Race Categories Not Represented',
    '% White',
    '% Students with Disabilities',
    '% English Language Learners',
    '% Poverty',
    'Number Tested - ELA',
    'Mean Scale Score - ELA',
    '# Level 1 - ELA',
    '% Level 1 - ELA',
    '# Level 2 - ELA',
    '% Level 2 - ELA',
    '# Level 3 - ELA',
    '% Level 3 - ELA',
    '# Level 4 - ELA',
    '% Level 4 - ELA',
    '# Level 3+4 - ELA',
    '% Level 3+4 - ELA',
    'Number Tested - Math',
    'Mean Scale Score - Math',
    '# Level 1 - Math',
    '% Level 1 - Math',
    '# Level 2 - Math',
    '% Level 2 - Math',
    '# Level 3 - Math',
    '% Level 3 - Math',
    '# Level 4 - Math',
    '% Level 4 - Math',
    '# Level 3+4 - Math',
    '% Level 3+4 - Math',
    '# Students Grade 8',
    '# SHSAT Testers'
]
df = df[columns]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 578 entries, 01M034 to 84X717
# Data columns (total 40 columns):
# School Name                                   578 non-null object
# Borough                                       578 non-null object
# Charter School                                578 non-null int64
# Economic Need Index                           578 non-null float64
# % Female                                      578 non-null float64
# % Male                                        578 non-null float64
# % Asian                                       578 non-null float64
# % Black                                       578 non-null float64
# % Hispanic                                    578 non-null float64
# % Multiple Race Categories Not Represented    578 non-null float64
# % White                                       578 non-null float64
# % Students with Disabilities                  578 non-null float64
# ...

# %% [markdown]
# *null values for '# SHSAT Testers' means there were 5- students taking the test*
#
# ---
#
# All clean and beautiful!

# %%
df.head()
# Out:
#                                   School Name    Borough  Charter School  \
# DBN
# 01M034         P.S. 034 Franklin D. Roosevelt  Manhattan               0
# 01M140                 P.S. 140 Nathan Straus  Manhattan               0
# 01M184                   P.S. 184m Shuang Wen  Manhattan               0
# 01M188             P.S. 188 The Island School  Manhattan               0
# 01M301  Technology, Arts, and Sciences Studio  Manhattan               0
#
#         Economic Need Index  % Female    % Male   % Asian   % Black  \
# DBN
# 01M034             0.939015  0.450450  0.549550  0.033033  0.318318
# 01M140             0.905606  0.490566  0.509434  0.056604  0.123989
# 01M184             0.639987  0.498538  0.501462  0.694444  0.036550
# 01M188             0.953106  0.427252  0.572748  0.018476  0.293303
# 01M301             0.833962  0.452830  0.547170  0.037736  0.320755
#
#         % Hispanic  % Multiple Race Categories Not Represented  \
# DBN
# ...
